# %%
import os
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline

# %%
fig_dir = "../figures/umap_out/3/"
if not os.path.exists(fig_dir):
    os.mkdir(fig_dir)

# %%
meta_df = pd.read_csv("../data/meta.tsv",sep="\t", index_col=0)
meta_df
# Out:
#            Timepoint Stimuli  Sample Genotype Stimuli Names
# 0_2G3              3       G       2       WT         Nec1s
# 1_2G3              3       G       2       WT         Nec1s
# 2_2G3              3       G       2       WT         Nec1s
# 3_2G3              3       G       2       WT         Nec1s
# 4_2G3              3       G       2       WT         Nec1s
# ...              ...     ...     ...      ...           ...
# 4592_4B46         46       B       4       WT           zVD
# 4593_4B46         46       B       4       WT           zVD
# 4594_4B46         46       B       4       WT           zVD
# 4595_4B46         46       B       4       WT           zVD
# 4596_4B46         46       B       4       WT           zVD
#
# [25577941 rows x 5 columns]

# %%
raw = pickle.load(open("../data/processed/data_df_log10_z.p","rb"))
raw
# Out:
#            Cell Size  Cell Circularity  Cell Aspect Ratio  \
# 0_2G3       4.514737        -35.280948           4.073811
# 1_2G3      -0.206776        -23.196179          18.581889
# 2_2G3      -1.666082        -10.317551          10.892828
# 3_2G3      -1.082179        -15.445497          13.969401
# 4_2G3      -3.274187          0.564852           2.419749
# ...              ...               ...                ...
# 4592_4B46   0.928028          0.081115          -0.633219
# 4593_4B46   1.411085         -5.132832           4.370616
# 4594_4B46   0.641696         -0.609064           1.004787
# 4595_4B46  -1.253652          0.564852           0.284477
# 4596_4B46   0.557869         -3.073115           3.642955
#
#            Cell Tracker Intensity  PI Intensity  AnexinV Intensity
# 0_2G3                   -0.549886     -1.508243          -1.286249
# 1_2G3                   -1.036545     -1.525713          -1.696325
# 2_2G3                   -0.955933     -1.518481          -1.653310
# 3_2G3                   -0.843089     -1.504416          -1.656892
# 4_2G3                   -0.857998     -1.514578          -1.643740
# ...                           ...           ...                ...
# 4592_4B46               -1.657626     -1.026704           0.483296
# 4593_4B46               -2.036756     -0.607149           0.626727
# 4594_4B46               -1.695808      0.370317           0.438746
# 4595_4B46               -0.612722      1.667999           0.419938
# 4596_4B46               -1.979479     -0.911976           0.342143
#
# [25577941 rows x 6 columns]

# %%
import numpy as np

# %%
for curr_param in glob.glob("../results/umap_out/3/*p"):
    print(curr_param)
    inp = pickle.load(open(curr_param,"rb"))
    if not len(inp) == 2:
        continue
    embedding,samples_inds = inp[0], inp[1]
    curr_df = meta_df.loc[samples_inds]
    curr_df["embedding_1"] = embedding[:,0]
    curr_df["embedding_2"] = embedding[:,1]
    curr_df = pd.merge(curr_df, raw,how='inner',left_index=True, right_index=True)
    
    # Create figures
    color_labels = curr_df["Stimuli Names"].unique()
    rgb_values = (sns.color_palette("Set2", len(color_labels)))
    color_map = dict(zip(color_labels, rgb_values))

    plt.figure(figsize=(15,15))
    pallete=sns.color_palette("bright", len(color_labels))
    sns.scatterplot(data=curr_df,x="embedding_1", y="embedding_2", palette=pallete, hue='Stimuli Names',style="Genotype",
                            size=0.5)

    plt.legend(loc='upper right')
    
    neigh = curr_param.strip(".p").split("_")[-2]
    dist = curr_param.strip(".p").split("_")[-1]
    title = f"Neighbors={neigh}\nMinimum Distance={dist}\nN Samples = {len(embedding)}"
    plt.title(title)
    plt.savefig(os.path.join(fig_dir,f"{neigh}_{dist}_umap_stimuli.png"))
    plt.savefig(os.path.join(fig_dir,f"{neigh}_{dist}_umap_stimuli.pdf"))
    plt.close()
    
    for i in raw.columns.values:
        plt.figure(figsize=(15,15))
        pallete=sns.color_palette("bright", len(color_labels))
        sns.scatterplot(data=curr_df,x="embedding_1", y="embedding_2", hue=i,
                        style="Genotype", size=0.5)
        #curr_df.plot.scatter("embedding_1","embedding_2", hue=curr_df['Stimuli'])#.map(color_map),s=0.5)
        plt.legend(loc='upper right')
        plt.savefig(os.path.join(fig_dir,f"{neigh}_{dist}_{i.replace(' ','')}.png"))
        plt.savefig(os.path.join(fig_dir,f"{neigh}_{dist}_{i.replace(' ','')}.pdf"))
        plt.close()
# Out:
# ../results/umap_out/3/embedding_2_100_0.1.p
# ../results/umap_out/3/embedding_0_10_0.p
# ../results/umap_out/3/embedding_0_5_0.1.p
# ../results/umap_out/3/embedding_1_200_0.1.p
# ../results/umap_out/3/embedding_0_15_0.1.p
# ../results/umap_out/3/embedding_0_3_0.1.p
# ../results/umap_out/3/embedding_0_100_0.p
# ../results/umap_out/3/embedding_1_5_0.1.p
# ../results/umap_out/3/embedding_2_3_0.1.p
# ../results/umap_out/3/embedding_0_100_0.1.p
# ../results/umap_out/3/embedding_0_200_0.1.p
# ../results/umap_out/3/embedding_1_3_0.p
# ../results/umap_out/3/embedding_0_15_0.p
# ../results/umap_out/3/embedding_2_15_0.1.p
# ../results/umap_out/3/embedding_2_5_0.1.p
# ../results/umap_out/3/embedding_2_200_0.1.p
# ../results/umap_out/3/embedding_2_3_0.p
# ../results/umap_out/3/embedding_1_10_0.1.p
# ../results/umap_out/3/embedding_0_3_0.p
# ../results/umap_out/3/embedding_1_200_0.p
# ../results/umap_out/3/embedding_1_5_0.p
# ../results/umap_out/3/embedding_1_100_0.p
# ../results/umap_out/3/embedding_0_5_0.p
# ../results/umap_out/3/embedding_2_10_0.1.p
# ../results/umap_out/3/embedding_0_200_0.p
# ../results/umap_out/3/embedding_1_3_0.1.p
# ../results/umap_out/3/embedding_2_10_0.p
# ../results/umap_out/3/embedding_1_15_0.1.p
# ../results/umap_out/3/embedding_1_100_0.1.p
# ../results/umap_out/3/embedding_1_10_0.p
# ../results/umap_out/3/embedding_2_15_0.p
# ../results/umap_out/3/embedding_0_10_0.1.p
# ../results/umap_out/3/embedding_2_200_0.p
# ../results/umap_out/3/embedding_2_5_0.p
# ../results/umap_out/3/embedding_2_100_0.p
# ../results/umap_out/3/embedding_1_15_0.p
